# %%
import os
import pandas as pd

# %%
df = pd.read_csv(os.path.join("..", "data", "iwildcam_2022_cameratrapai_pt_train.csv"))

# %%
available_species = [col for col in df.columns if col.startswith("gt_")]
# Out:
#         Unnamed: 0  split  seq_num_frames  location                 datetime  \
# 0                0  train               6         3  2013-06-05 05:44:19.000
# 1                1  train               6         3  2013-06-05 05:44:20.000
# 2                2  train               6         3  2013-06-05 05:44:21.000
# 3                3  train               6         3  2013-06-05 05:44:22.000
# 4                4  train               6         3  2013-06-05 05:44:23.000
# ...            ...    ...             ...       ...                      ...
# 201394      201394  train               6       165  2013-06-05 13:08:12.000
# 201395      201395  train               6       165  2013-06-05 13:08:19.000
# 201396      201396  train               6       165  2013-06-05 13:08:42.000
# 201397      201397  train               6       165  2013-06-05 13:08:48.000
# 201398      201398  train               6       165  2013-06-05 13:08:55.000
#
# ...
